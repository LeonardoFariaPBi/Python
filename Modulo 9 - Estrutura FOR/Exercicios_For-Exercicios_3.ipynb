# %% [markdown]
# # Exercícios
#
# ## 1. Calculando % de uma lista
#
# Faremos algo parecido com "filtrar" uma lista. Mais pra frente no curso aprenderemos outras formas de fazer isso, mas com o nosso conhecimentoa atual já conseguimos resolver o desafio.
#
# Digamos que a gente tenha uma lista de vendedores e ao invés de saber todos os vendedores que bateram a meta, eu quero conseguir calcular o % de vendedores que bateram a meta. Ou seja, se temos 10 vendedores e 3 bateram a meta, temos 30% dos vendedores que bateram a meta.

# %%
meta = 10000
vendas = [
    ['João', 15000],
    ['Julia', 27000],
    ['Marcus', 9900],
    ['Maria', 3750],
    ['Ana', 10300],
    ['Alon', 7870],
]
#seu código aqui
vendedores_atingiram_meta = []
for venda in vendas:
    if venda[1] >= meta:
        vendedores_atingiram_meta.append(venda)
        
print(vendedores_atingiram_meta)
print('{:.1%} dos vendedores atingiram a meta'.format(len(vendedores_atingiram_meta)/len(vendas)))
# Out:
# [['João', 15000], ['Julia', 27000], ['Ana', 10300]]
# 50.0% dos vendedores atingiram a meta

# %%
#seu código aqui
vendedores_atingiram_meta = 0

for venda in vendas:
    if venda[1] >= meta:
        vendedores_atingiram_meta += 1
print('{:.1%} dos vendedores atingiram a meta'.format(vendedores_atingiram_meta/len(vendas)))
# Out:
# 50.0% dos vendedores atingiram a meta

# %% [markdown]
# - Vamos resolver de 2 formas:
#     1. Criando uma lista auxiliar apenas com os vendedores que bateram a meta
#     2. Fazendo o cálculo diretamente na lista que já temos

# %% [markdown]
# ## Para treinar uma estrutura parecida, crie um código para responder: quem foi o vendedor que mais vendeu?

# %%
meta = 10000
vendas = [
    ['João', 15000],
    ['Julia', 27000],
    ['Marcus', 9900],
    ['Maria', 3750],
    ['Ana', 10300],
    ['Alon', 7870],
]
#seu código aqui
vendedores_atingiram_meta = []
for venda in vendas:
    if venda[1] >= meta:
        vendedores_atingiram_meta.append(venda)
        top1 = max(vendedores_atingiram_meta)
print(vendedores_atingiram_meta)
print('{:.1%} dos vendedores atingiram a meta'.format(len(vendedores_atingiram_meta)/len(vendas)))
print('O vendedor que mais vendeu foi {} com {} vendas.'.format(top1[0],top1[1]))
# Out:
# [['João', 15000], ['Julia', 27000], ['Ana', 10300]]
# 50.0% dos vendedores atingiram a meta
# O vendedor que mais vendeu foi Julia com 27000 vendas.

# %%
melhor_vendedor = ''
maior_vendas = 0

for vendas in vendas:
    if vendas[1] > maior_vendas:
        maior_vendas = vendas[1]
        melhor_vendedor = vendas[0]
print('O vendedor que mais vendeu foi {} com {} vendas.'.format(melhor_vendedor, maior_vendas))
# Out:
# O vendedor que mais vendeu foi Julia com 27000 vendas.
