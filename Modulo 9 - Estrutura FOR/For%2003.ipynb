# %% [markdown]
# # for + if
#
# ### Estrutura:

# %% [raw]
# for item in lista:
#     if condicao:
#         faça alguma coisa
#     else:
#         outra coisa

# %% [markdown]
# Digamos que a gente esteja analisando a meta de vendas de vários funcionários de uma empresa. A meta de vendas é de 1000 reais em 1 dia.
#
# Temos uma lista com as vendas de todos os funcionários e quero calcular qual o % de pessoas que bateram a meta.

# %%
vendas = [1200, 300, 800, 1500, 1900, 2750, 400, 20, 23, 70, 90, 80, 1100, 999, 900, 880, 870, 50, 1111, 120, 300, 450, 800]
meta = 1000
qntd_meta = 0

for venda in vendas:
    if venda >= meta:
        print(f'Venda de {venda} atingiu a meta!')
        qntd_meta += 1
    else:
        print(f'Venda de {venda} não atingiu a meta.')
print(f'Quantidade de vendas que atingiram a meta: {qntd_meta}')
# Out:
# Venda de 1200 atingiu a meta!
# Venda de 300 não atingiu a meta.
# Venda de 800 não atingiu a meta.
# Venda de 1500 atingiu a meta!
# Venda de 1900 atingiu a meta!
# Venda de 2750 atingiu a meta!
# Venda de 400 não atingiu a meta.
# Venda de 20 não atingiu a meta.
# Venda de 23 não atingiu a meta.
# Venda de 70 não atingiu a meta.
# Venda de 90 não atingiu a meta.
# Venda de 80 não atingiu a meta.
# Venda de 1100 atingiu a meta!
# Venda de 999 não atingiu a meta.
# Venda de 900 não atingiu a meta.
# Venda de 880 não atingiu a meta.
# Venda de 870 não atingiu a meta.
# Venda de 50 não atingiu a meta.
# Venda de 1111 atingiu a meta!
# Venda de 120 não atingiu a meta.
# Venda de 300 não atingiu a meta.
# Venda de 450 não atingiu a meta.
# Venda de 800 não atingiu a meta.
# Quantidade de vendas que atingiram a meta: 6
