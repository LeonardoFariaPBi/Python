# %% [markdown]
# # Exercícios
#
# ## 1. Criando um Registro de Hóspedes
#
# Digamos que você está criando o sistema para registrar a chegada de hóspedes em um hotel. No hotel, os hóspedes podem ter quartos com 1, 2, 3 e 4 pessoas. Seu sistema deve conseguir:
#
# 1. Identificar quantas pessoas o hóspede que acabou de chegar vai ter no quarto (perguntando por meio de input)
# 2. De acordo com a quantidade de pessoas do hóspede, ele deve fazer um for para perguntar o cpf e o nome de cada pessoa, a fim de registrá-la no quarto (2 inputs para cada pessoa, 1 para o cpf e outro para o nome)
# 3. O seu programa então deve gerar uma lista com todas as pessoas que ficarão no quarto em que cada item dessa lista é o nome da pessoa e o cpf da pessoa, assim:

# %% [raw]
# quarto = [
#     ['João', 'cpf:00000000000'],
#     ['Julia', 'cpf:11111111111'],
#     ['Marcus', 'cpf:22222222222'],
#     ['Maria', 'cpf:33333333333'],
# ]

# %% [markdown]
# - Para simplificar, não vamos nos preocupar com possibilidades de "tentar colocar mais de 1 hóspede, digitar o cpf errado, etc. Nosso objetivo é treinar a criação de uma rotina de cadastro

# %%
#seu código aqui
qntd_pessoas = int(input("Digite a quantidade de pessoas: "))
quarto = []
for i in range(qntd_pessoas):
    nome = input(f"Digite o nome da {i+1}ª pessoa: ")
    idade = int(input(f"Digite a idade da {i+1}ª pessoa: "))
    pessoa = {'nome': nome, 'idade': idade}
    quarto.append(pessoa)
print(quarto)
# Out:
# [{'nome': 'joao', 'idade': 12}, {'nome': 'maria', 'idade': 15}, {'nome': 'julia', 'idade': 19}]

# %%
print(quarto)
# Out:
# [{'nome': 'joao', 'idade': 12}, {'nome': 'maria', 'idade': 15}, {'nome': 'julia', 'idade': 19}]

# %% [markdown]
# ## 2. Análise de Vendas
#
# Nesse exercício vamos fazer uma "análise simples" de atingimento de Meta.
#
# Temos uma lista com os vendedores e os valores de vendas e queremos identificar (printar) quais os vendedores que bateram a meta e qual foi o valor que eles venderam.

# %%
meta = 10000
vendas = [
    ['João', 15000],
    ['Julia', 27000],
    ['Marcus', 9900],
    ['Maria', 3750],
    ['Ana', 10300],
    ['Alon', 7870],
]
#seu código aqui
for i in range(len(vendas)):
    if vendas[i][1] >= meta:
        print(f'{vendas[i][0]} atingiu a meta com {vendas[i][1]} em vendas.')
    else:
        print(f'{vendas[i][0]} não atingiu a meta, vendeu apenas {vendas[i][1]}.')
# Out:
# João atingiu a meta com 15000 em vendas.
# Julia atingiu a meta com 27000 em vendas.
# Marcus não atingiu a meta, vendeu apenas 9900.
# Maria não atingiu a meta, vendeu apenas 3750.
# Ana atingiu a meta com 10300 em vendas.
# Alon não atingiu a meta, vendeu apenas 7870.

# %% [markdown]
# ## 3. Comparação com Ano Anterior
#
# Digamos que você está analisando as vendas de produtos de um ecommerce e quer identificar quais produtos tiveram no ano de 2020 mais vendas do que no ano de 2019, para reportar isso para a diretoria.
#
# Sua resposta pode ser um print de cada produto, qual foi a venda de 2019, a venda de 2020 e o % de crescimento de 2020 para 2019.
#
# Lembrando, para calcular o % de crescimento de um produto de um ano para o outro, podemos fazer: (vendas_produto2020/vendas_produto2019 - 1)
#
# Dica: lembre do enumerate, ele pode facilitar seu "for"

# %%
produtos = ['iphone', 'galaxy', 'ipad', 'tv', 'máquina de café', 'kindle', 'geladeira', 'adega', 'notebook dell', 'notebook hp', 'notebook asus', 'microsoft surface', 'webcam', 'caixa de som', 'microfone', 'câmera canon']
vendas2019 = [558147,712350,573823,405252,718654,531580,973139,892292,422760,154753,887061,438508,237467,489705,328311,591120]
vendas2020 = [951642,244295,26964,787604,867660,78830,710331,646016,694913,539704,324831,667179,295633,725316,644622,994303]
#seu código aqui

for i in range(len(produtos)):
    total_vendas = vendas2019[i] + vendas2020[i]
    percentual_crescimento = ((vendas2020[i] / vendas2019[i]) - 1) * 100
    print(f'O total de vendas do produto {produtos[i]} em 2019 e 2020 foi de {total_vendas} unidades. Equivalente a um crescimento de {percentual_crescimento:.2f}% entre os dois anos.')
print('Segunda Opcao de Resposta:')

for i, produto in enumerate(produtos):
    total_vendas = vendas2019[i] + vendas2020[i]
    percentual_crescimento = ((vendas2020[i] / vendas2019[i]) - 1) * 100
    print(f'O total de vendas do produto {produto} em 2019 e 2020 foi de {total_vendas} unidades. Equivalente a um crescimento de {percentual_crescimento:.2f}% entre os dois anos.')
# Out:
# O total de vendas do produto iphone em 2019 e 2020 foi de 1509789 unidades. Equivalente a um crescimento de 70.50% entre os dois anos.
# O total de vendas do produto galaxy em 2019 e 2020 foi de 956645 unidades. Equivalente a um crescimento de -65.71% entre os dois anos.
# O total de vendas do produto ipad em 2019 e 2020 foi de 600787 unidades. Equivalente a um crescimento de -95.30% entre os dois anos.
# O total de vendas do produto tv em 2019 e 2020 foi de 1192856 unidades. Equivalente a um crescimento de 94.35% entre os dois anos.
# O total de vendas do produto máquina de café em 2019 e 2020 foi de 1586314 unidades. Equivalente a um crescimento de 20.73% entre os dois anos.
# O total de vendas do produto kindle em 2019 e 2020 foi de 610410 unidades. Equivalente a um crescimento de -85.17% entre os dois anos.
# O total de vendas do produto geladeira em 2019 e 2020 foi de 1683470 unidades. Equivalente a um crescimento de -27.01% entre os dois anos.
# ...
