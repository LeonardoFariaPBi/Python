# %% [markdown]
# # Formas de interromper um for
#
# ### 2 Opções:
#
# - break -> interrompe e finaliza o for
# - continue -> interrompe e vai para o próximo item do for

# %%
vendas = [100, 150, 1500, 2000, 120]

# %% [markdown]
# - Caso 1: Se todas as vendas forem acima da meta, a loja ganha bônus

# %%
meta = 110

# %% [markdown]
# - Caso 2: Exiba quem bateu a meta

# %%
vendedores = ['João', 'Julia', 'Ana', 'José', 'Maria']
meta = 130

for i in range(len(vendas)):
    if vendas[i] >= meta:
        print(f"Parabéns {vendedores[i]}! Você bateu a meta com {vendas[i]} vendas.")
# Out:
# Parabéns Julia! Você bateu a meta com 150 vendas.
# Parabéns Ana! Você bateu a meta com 1500 vendas.
# Parabéns José! Você bateu a meta com 2000 vendas.
