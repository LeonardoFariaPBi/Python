# %% [markdown]
# # Adicionar e Remover itens de uma lista
#
# Adicionar:<br>
# lista.append(item)
#
# Remover:<br>
# item_removido = lista.pop(indice)<br>
# lista.remove(item)
#
# Digamos que você está construindo o controle de produtos da Apple.<br>
# E a Apple lançou o IPhone 11 e irá tirar dos seus estoques o IPhone X

# %%
produtos = ['Apple TV', 'Mac', 'iPhone x', 'IPad', 'Apple Watch', 'Mac Book', 'Airpods']
print(produtos)
#Adicionar o iPhone 14 na lista 'CASE SENSITIVE'
produtos.append('iPhone 14')
print(produtos)
produtos.insert(2, 'iPad Pro')
print(produtos)
produtos.remove('IPad')
print(produtos)
# Out:
# ['Apple TV', 'Mac', 'iPhone x', 'IPad', 'Apple Watch', 'Mac Book', 'Airpods']
# ['Apple TV', 'Mac', 'iPhone x', 'IPad', 'Apple Watch', 'Mac Book', 'Airpods', 'iPhone 14']
# ['Apple TV', 'Mac', 'iPad Pro', 'iPhone x', 'IPad', 'Apple Watch', 'Mac Book', 'Airpods', 'iPhone 14']
# ['Apple TV', 'Mac', 'iPad Pro', 'iPhone x', 'Apple Watch', 'Mac Book', 'Airpods', 'iPhone 14']

# %% [markdown]
# ## Existem 2 formas de tratar o erro:
#
# 1. Criar um if para evitar que ele aconteça
#
# 2. Esperar que ele possa acontecer e tratar caso o erro aconteça com:

# %% [raw]
# try:
#     tentar fazer
# except:
#     caso dê errado

# %%
try:
    produtos.remove('Mac Book')
    print(produtos)
except:
    print('O produto não foi encontrado na lista.')
# Out:
# ['Apple TV', 'Mac', 'iPad Pro', 'iPhone x', 'Apple Watch', 'Airpods', 'iPhone 14']
