# %% [markdown]
# # Transformando Listas em Dicionários e Function zip
#
# ### Estrutura:
#
# - Dicionário com valores padrões:
#
# dicionario = dict.fromkeys(lista_chaves, valor_padrao)
#
# - Dicionário a partir de listas de tuplas:
#
# dicionario = dict(lista_tuplas)
#
# - Dicionário a partir de 2 listas:
#
# Passo 1: Transformar listas em lista de tuplas com o método zip<br>
# Passo 2: Transformar em dicionario
#
# lista_tuplas = zip(lista1, lista2)<br>
# dicionario = dict(lista_tuplas)

# %%
produtos = ['iphone', 'samsung galaxy', 'tv samsung', 'ps5', 'tablet', 'ipad', 'tv philco', 'notebook hp', 'notebook dell', 'notebook asus']
vendas = [15000, 12000, 10000, 14300, 1720, 1000, 2500, 1000, 17000, 2450]\

dicionario_vendas = dict.fromkeys(produtos, 0)
print(dicionario_vendas)
dicionario_vendas_tuplas = dict(zip(produtos, vendas))
print(dicionario_vendas_tuplas)
print('-' * 70)
for item in dicionario_vendas_tuplas.items():
    print(f'O produto {item[0]} teve o valor de R$ {item[1]:.2f} em vendas.')
# Out:
# {'iphone': 0, 'samsung galaxy': 0, 'tv samsung': 0, 'ps5': 0, 'tablet': 0, 'ipad': 0, 'tv philco': 0, 'notebook hp': 0, 'notebook dell': 0, 'notebook asus': 0}
# {'iphone': 15000, 'samsung galaxy': 12000, 'tv samsung': 10000, 'ps5': 14300, 'tablet': 1720, 'ipad': 1000, 'tv philco': 2500, 'notebook hp': 1000, 'notebook dell': 17000, 'notebook asus': 2450}
# ----------------------------------------------------------------------
# O produto iphone teve o valor de R$ 15000.00 em vendas.
# O produto samsung galaxy teve o valor de R$ 12000.00 em vendas.
# O produto tv samsung teve o valor de R$ 10000.00 em vendas.
# O produto ps5 teve o valor de R$ 14300.00 em vendas.
# O produto tablet teve o valor de R$ 1720.00 em vendas.
# O produto ipad teve o valor de R$ 1000.00 em vendas.
# O produto tv philco teve o valor de R$ 2500.00 em vendas.
# O produto notebook hp teve o valor de R$ 1000.00 em vendas.
# O produto notebook dell teve o valor de R$ 17000.00 em vendas.
# O produto notebook asus teve o valor de R$ 2450.00 em vendas.

# %% [markdown]
# - Quanto vendemos de ipad?

# %%
#fazendo por listas
indice = produtos.index('ipad')
print(f'O produto {produtos[indice]} teve o valor de R$ {vendas[indice]:.2f} em vendas.')
#fazendo por dicionario
print(f'O produto ipad teve o valor de R$ {dicionario_vendas_tuplas["ipad"]:.2f} em vendas.')
# Out:
# O produto ipad teve o valor de R$ 1000.00 em vendas.
# O produto ipad teve o valor de R$ 1000.00 em vendas.
