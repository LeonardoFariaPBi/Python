# %% [markdown]
# # Cuidado com o while -> Loop Infinito
#
# Sempre que for usar o comando while, lembre-se de ter certeza que o programa vai terminar em algum momento
#
# ### Exemplo
#
# Digamos que temos uma lista de vendedores e as quantidades vendidas e queremos identificar todos os vendedores que bateram a meta de 50 vendas.

# %%
vendas = [941, 852, 783, 714, 697, 686, 685, 670, 631, 453, 386, 371, 294, 269, 259, 218, 208, 163, 125, 102, 87, 47, 7]
vendedores = ['Maria', 'José', 'Antônio', 'João', 'Francisco', 'Ana', 'Luiz', 'Paulo', 'Carlos', 'Manoel', 'Pedro', 'Francisca', 'Marcos', 'Raimundo', 'Sebastião', 'Antônia', 'Marcelo', 'Jorge', 'Márcia', 'Geraldo', 'Adriana', 'Sandra', 'Luis']
meta = 50
i = 0
while vendas[i] > meta:
        print(f'O vendedor {vendedores[i]} bateu a meta com {vendas[i]} vendas!')
        i += 1
# Out:
# O vendedor Maria bateu a meta com 941 vendas!
# O vendedor José bateu a meta com 852 vendas!
# O vendedor Antônio bateu a meta com 783 vendas!
# O vendedor João bateu a meta com 714 vendas!
# O vendedor Francisco bateu a meta com 697 vendas!
# O vendedor Ana bateu a meta com 686 vendas!
# O vendedor Luiz bateu a meta com 685 vendas!
# O vendedor Paulo bateu a meta com 670 vendas!
# O vendedor Carlos bateu a meta com 631 vendas!
# O vendedor Manoel bateu a meta com 453 vendas!
# O vendedor Pedro bateu a meta com 386 vendas!
# O vendedor Francisca bateu a meta com 371 vendas!
# O vendedor Marcos bateu a meta com 294 vendas!
# O vendedor Raimundo bateu a meta com 269 vendas!
# O vendedor Sebastião bateu a meta com 259 vendas!
# O vendedor Antônia bateu a meta com 218 vendas!
# O vendedor Marcelo bateu a meta com 208 vendas!
# O vendedor Jorge bateu a meta com 163 vendas!
# O vendedor Márcia bateu a meta com 125 vendas!
# O vendedor Geraldo bateu a meta com 102 vendas!
# O vendedor Adriana bateu a meta com 87 vendas!
