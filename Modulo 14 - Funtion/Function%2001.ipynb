# %% [markdown]
# # Function Python
#
# ### O que é?
#
# As functions são blocos de código que servem 1 único propósito, fazem uma ação específica.
#
# ### Estrutura Básica

# %% [raw]
# def nome_funcao():
#     faça alguma coisa
#     faça outra coisa
#     return valor_final

# %% [markdown]
# - Exemplo: vamos criar uma função de cadastro de um Produto. Essa função deve garantir que o produto cadastrado está em letra minúscula.

# %%
def cadastrar_produto():
    produto = input("Digite o nome do produto: ")
    produto = produto.casefold()
    print('Produto {} registrado com sucesso!'.format(produto))

# %%
for i in range(3):
    cadastrar_produto()
print('Todos os produtos foram cadastrados com sucesso!')
print('Encerrando o programa...')
# Out:
# Produto feijao registrado com sucesso!
# Produto laranja registrado com sucesso!
# Produto uva registrado com sucesso!
# Todos os produtos foram cadastrados com sucesso!
# Encerrando o programa...
